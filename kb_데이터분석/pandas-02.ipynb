# %%
import pandas as pd
url = "https://raw.githubusercontent.com/seoul-opengov/opengov/master/expense_list2021/202112_expense_list.csv"
seoul_exp_01 = pd.read_csv(url)
seoul_exp_01
# Out:
#             nid                                              title  \
# 0      25019637           2021년 12월 사업소 중부공원녹지사업소 시설과 업무추진비 - 부서운영
# 1      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 2      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 3      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 4      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# ...         ...                                                ...
# 10339  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10340  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10341  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10342  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10343  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
#
#                                                url dept_nm_lvl_1  \
# 0      http://opengov.seoul.go.kr/expense/25019637           사업소
# ...

# %%
mem01 = pd.DataFrame([
    [70,80,90],
    [90,80,80],
])
mem01.index = ['홍','김']
mem01.columns = ['국어','수학','영어']
mem01
# Out:
#    국어  수학  영어
# 홍  70  80  90
# 김  90  80  80

# %%
mem01.plot()
# Out:
# <AxesSubplot:>
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50689 missing from current font.
# ...

# %%
mem01.T
# Out:
#      홍   김
# 국어  70  90
# 수학  80  80
# 영어  90  80

# %%
seoul_exp_01.columns
# Out:
# Index(['nid', 'title', 'url', 'dept_nm_lvl_1', 'dept_nm_lvl_2',
#        'dept_nm_lvl_3', 'dept_nm_lvl_4', 'dept_nm_lvl_5', 'exec_yr',
#        'exec_month', 'expense_budget', 'expense_execution', 'category',
#        'dept_nm_full', 'exec_dt', 'exec_loc', 'exec_purpose', 'target_nm',
#        'payment_method', 'exec_amount'],
#       dtype='object')

# %%
seoul_exp_01['dept_nm_lvl_1'].unique()
# column에 사용된 값들 중 중복되지 않는 값들을 보여줌
# Out:
# array(['사업소', '소방재난본부(소방서)', '서울시본청', '의회사무처'], dtype=object)

# %%
seoul_exp_01['dept_nm_lvl_1'].shape
# Out:
# (10344,)

# %%
seoul_exp_01['dept_nm_lvl_2'].unique()
# Out:
# array(['중부공원녹지사업소', '은평병원', '상수도사업본부', '서울종합방재센터', '119특수구조단', '시립미술관',
#        '자치경찰위원회', '주택정책실', '어린이병원', '소방재난본부', '보건환경연구원', '행정국', '재무국',
#        '여성가족정책실', '평생교육국', '데이터센터', '서울식물원', '도시기반시설본부', '시민건강국',
#        '체육시설관리사업소', '기후환경본부', '서울역사박물관', '균형발전본부', '관광체육국', '물재생센터',
#        '서울시립대학교', '대변인', '언론홍보실', '경제정책실', '서울도서관', '시민소통기획관', '복지정책실',
#        '안전총괄실', '구로소방서', '노동공정상생정책관', '민생사법경찰단', '기획조정실', '비상기획관',
#        '서부공원녹지사업소', '동부공원녹지사업소', '도시계획국', '관악소방서', '시민협력국', '남북협력추진단',
#        '소방학교', '마포소방서', '도로사업소', '서울공예박물관', '서울시립과학관', '영등포소방서', '서울기록원',
#        '서북병원', '공공개발기획단', '도시교통실', '중부소방서', '입법담당관', '기술심사담당관', '인재개발원',
#        '동대문소방서', '문화본부', '푸른도시국', '광진소방서', '문화체육관광전문위원실', '스마트도시정책관',
#        '물순환안전국', '강북소방서', '행정2부시장', '감사위원회', '행정자치전문위원실', '강서소방서',
#        '서울대공원', '송파소방서', '동작소방서', '아동복지센터', '환경수자원전문위원실', '청와대소방대',
#        '성북소방서', '예산정책담당관', '중랑소방서', '차량정비센터', '강동소방서', '의사담당관', '시민권익담당관',
# ...

# %%
seoul_exp_01['dept_nm_lvl_2'].unique().shape    #부서 개수
# Out:
# (115,)

# %%
seoul_exp_01['dept_nm_lvl_5'].unique()
# Out:
# array([nan, '물순환연구과', '건축총괄과', '계획과', '연구기획과', '계획설계과', '수처리연구과', '생산관리과',
#        '수질연구과', '요금제도과', '방재시설과'], dtype=object)

# %%
seoul_exp_01['exec_loc'].unique()
# Out:
# array(['㈜그린주의(중량구 봉화산로123)', '오도르아뜰리에(은평구 서오릉로 177)',
#        '행복한베이커리&카페(은평구 백련산로 90)', ..., '고기사람(서대문구 충정로4길 26)',
#        '장수숯불갈비(성동구 성덕정길40)', '장수숯불갈비(성동구 성덕정길39)'], dtype=object)

# %%
# fancy indexing
seoul_exp_01[
    ['exec_dt',
    'exec_loc',
    'exec_amount']
]
# Out:
#                 exec_dt                 exec_loc  exec_amount
# 0      2021-12-17 11:00       ㈜그린주의(중량구 봉화산로123)       347900
# 1      2021-12-23 11:18    오도르아뜰리에(은평구 서오릉로 177)        30000
# 2      2021-12-20 14:50  행복한베이커리&카페(은평구 백련산로 90)        30000
# 3      2021-12-20 14:46          키지아(은평구 백련산로4길)        26150
# 4      2021-12-20 12:40  수빈떡갈비(서대문구 연희로25길 31-3)        89000
# ...                 ...                      ...          ...
# 10339  2021-12-21 19:44      고기사람(서대문구 충정로4길 26)        97000
# 10340  2021-12-07 11:57       장수숯불갈비(성동구 성덕정길40)       120000
# 10341  2021-12-02 12:07       장수숯불갈비(성동구 성덕정길39)       116000
# 10342  2021-12-28 16:48         현대마트(성동구 성덕정길29)       113180
# 10343  2021-12-28 10:15          서울시청매점(중구 덕수궁길)        84000
#
# [10344 rows x 3 columns]

# %%
# fancy indexing
seoul_exp_01[10:20]
# Out:
#          nid                                           title  \
# 10  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 11  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 12  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 13  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 14  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 15  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 16  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 17  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 18  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 19  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
#
#                                             url dept_nm_lvl_1 dept_nm_lvl_2  \
# 10  http://opengov.seoul.go.kr/expense/25040705           사업소       상수도사업본부
# 11  http://opengov.seoul.go.kr/expense/25040705           사업소       상수도사업본부
# ...

# %%
b1 = seoul_exp_01['dept_nm_lvl_1']=="서울시본청"
print(b1)
se1 = seoul_exp_01[b1] # True에 해당하는 행 추출.
#서울시 본청에서 지출한 정보들만 뽑아내는 것. 
se1['dept_nm_lvl_1'].unique()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10339    False
# 10340    False
# 10341    False
# 10342    False
# 10343    False
# Name: dept_nm_lvl_1, Length: 10344, dtype: bool
# array(['서울시본청'], dtype=object)

# %%
mem01.rename(columns={"국어":"한문"})
#소스를 바꾼 새로운 data frame을 반환.
# 결국 우리가 보는 결과본은 복사본을 반환하는 것. 
# 뭘 실행했을 때 아무것도 결과가 나오지 않는다면 그건 원본이 바뀌었단 소리.
# 복사본이 반환되는 경우는 원본은 바뀌지 않고 결과가 도출됨.
# Out:
#    한문  수학  영어
# 홍  70  80  90
# 김  90  80  80

# %%
mem01
# Out:
#    국어  수학  영어
# 홍  70  80  90
# 김  90  80  80

# %%
mem01.rename(columns={'영어':'영어2'},inplace=True)
mem01
# Out:
#    국어  수학  영어2
# 홍  70  80   90
# 김  90  80   80

# %%
seoul_apt = pd.read_csv("./아파트(매매)__실거래가_20220401113837.csv",
           encoding="EUC-KR",
           skiprows=15,  # 위에 설명문 스킵해야 제대로 열림. exel : 16 & csv : 15
           thousands ="," # 금액에서 1000자리 구분 글자를 사용중이니 이걸 지우고 해석하세요.라는 의미
)
seoul_apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32139 entries, 0 to 32138
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       32139 non-null  object
#  1   번지        32127 non-null  object
#  2   본번        32135 non-null  float64
#  3   부번        32135 non-null  float64
#  4   단지명       32139 non-null  object
#  5   전용면적(㎡)   32139 non-null  float64
#  6   계약년월      32139 non-null  int64
#  7   계약일       32139 non-null  int64
#  8   거래금액(만원)  32139 non-null  int64
#  9   층         32139 non-null  int64
#  10  건축년도      32139 non-null  int64
#  11  도로명       32139 non-null  object
#  12  해제사유발생일   964 non-null    float64
#  13  거래유형      32139 non-null  object
#  14  중개사소재지    32139 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 3.7+ MB

# %%
import seaborn as sns
# seaborn = 차트 그리는 api.

titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
 titanic.describe(include="object")  # include="object" : 문자열에 대한 통계.
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
titanic["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
seoul_apt.sort_values(by="거래금액(만원)")
# Out:
#                  시군구      번지     본번    부번    단지명   전용면적(㎡)    계약년월  계약일  \
# 10800  서울특별시 노원구 공릉동   395-7  395.0   7.0  진명비베레   12.5172  202105   13
# 9587   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202104   17
# 9595   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202108   18
# 7717   서울특별시 광진구 화양동  110-37  110.0  37.0   화양타워   15.1800  202104   19
# 9601   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202202    9
# ...              ...     ...    ...   ...    ...       ...     ...  ...
# 1582   서울특별시 강남구 청담동     129  129.0   0.0  PH129  273.9600  202107    7
# 28692  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.6700  202109    9
# 28693  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.9500  202111   24
# 28694  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.6700  202111   26
# 28695  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.9500  202112   13
#
#        거래금액(만원)   층  건축년도          도로명  해제사유발생일  거래유형  중개사소재지
# ...

# %%
seoul_apt["해제사유발생일"].notna().sum() # nan값이 없는 value값들은 몇 개?
# Out:
# 964

# %%
seoul_apt[seoul_apt["해제사유발생일"].notna()]
# Out:
#                  시군구    번지      본번   부번        단지명   전용면적(㎡)    계약년월  계약일  \
# 5      서울특별시 강남구 개포동  1282  1282.0  0.0  개포래미안포레스트   49.9200  202105   22
# 6      서울특별시 강남구 개포동  1282  1282.0  0.0  개포래미안포레스트   59.9200  202105   22
# 53     서울특별시 강남구 개포동   649   649.0  0.0       경남2차  149.2100  202104   26
# 66     서울특별시 강남구 개포동   138   138.0  0.0   디에이치아너힐즈   59.8072  202106    5
# 98     서울특별시 강남구 개포동  1280  1280.0  0.0   래미안블레스티지   59.8970  202108   19
# ...              ...   ...     ...  ...        ...       ...     ...  ...
# 31832  서울특별시 중랑구 신내동   783   783.0  0.0         성원   84.3200  202106   15
# 31927  서울특별시 중랑구 신내동   650   650.0  0.0      신내6대주   59.7600  202109    1
# 31963  서울특별시 중랑구 신내동   657   657.0  0.0      신내9진흥   33.1800  202106   23
# 31991  서울특별시 중랑구 신내동   816   816.0  0.0   신내우디안1단지  101.6500  202105   22
# 32038  서울특별시 중랑구 신내동   479   479.0  0.0      중앙하이츠   84.9700  202110   25
#
#        거래금액(만원)   층  건축년도          도로명     해제사유발생일 거래유형 중개사소재지
# ...

# %%
seoul_apt.sort_values(
    by = "거래금액(만원)",
    ascending = False).head(10)
# Out:
#                  시군구      번지     본번    부번         단지명   전용면적(㎡)    계약년월  계약일  \
# 28695  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.9500  202112   13
# 28694  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202111   26
# 28693  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.9500  202111   24
# 28692  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202109    9
# 28691  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202108    4
# 1582   서울특별시 강남구 청담동     129  129.0   0.0       PH129  273.9600  202107    7
# 28678  서울특별시 용산구 한남동     386  386.0   0.0    르가든더메인한남  228.3400  202109   15
# 1583   서울특별시 강남구 청담동     129  129.0   0.0       PH129  273.9600  202111   25
# 28671  서울특별시 용산구 한남동     829  829.0   0.0       나인원한남  244.3478  202112    2
# 1610   서울특별시 강남구 청담동  129-16  129.0  16.0  상지리츠빌카일룸3차  265.4700  202105   10
#
#        거래금액(만원)   층  건축년도          도로명     해제사유발생일  거래유형  중개사소재지
# ...

# %%
print(seoul_apt.loc[0,"단지명"])
print()
print(seoul_apt.loc[0,:]) # Series. 한개의 행만 뽑음. 1차원으로 뽑기 때문에 column필요 없고 index만 있으면 됨.
print()
seoul_apt.loc[[0],:] # [0]이렇게 감싸면 하나의 0번행이 하나의 DataFrame으로나옴.
# [0] -> 2차원 형태로 뽑겠다는 것. column정보 뿐만 아니라 행 정보도 들어가야 함.
# Out:
# 개포2차현대아파트(220)
#
# 시군구          서울특별시 강남구 개포동
# 번지                   655-2
# 본번                   655.0
# 부번                     2.0
# 단지명         개포2차현대아파트(220)
# 전용면적(㎡)              77.75
# 계약년월                202104
# 계약일                     15
# 거래금액(만원)            174000
# 층                        9
# 건축년도                  1988
# 도로명                언주로 103
# 해제사유발생일                NaN
# 거래유형                     -
# 중개사소재지                   -
# Name: 0, dtype: object
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202104   15
#
#    거래금액(만원)  층  건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 0    174000  9  1988  언주로 103      NaN    -      -

# %%
seoul_apt.loc[[0],:]
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202104   15
#
#    거래금액(만원)  층  건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 0    174000  9  1988  언주로 103      NaN    -      -

# %%
seoul_apt.loc[:,["단지명","거래금액(만원)"]]
# Out:
#                   단지명  거래금액(만원)
# 0      개포2차현대아파트(220)    174000
# 1      개포6차우성아파트1동~8동    195000
# 2      개포6차우성아파트1동~8동    200000
# 3      개포6차우성아파트1동~8동    220000
# 4      개포6차우성아파트1동~8동    215000
# ...               ...       ...
# 32134  한신아파트(103~109)     83200
# 32135         한영(101)     50000
# 32136         한영(102)     49500
# 32137         한영(103)     30000
# 32138         한영(103)     61500
#
# [32139 rows x 2 columns]

# %%
titanic.loc[2:5,"class":"deck"]
# Out:
#    class    who  adult_male deck
# 2  Third  woman       False  NaN
# 3  First  woman       False    C
# 4  Third    man        True  NaN
# 5  Third    man        True  NaN

# %%
target = titanic["sex"] == "female"
titanic.loc[titanic["sex"]=="female","age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
target = (titanic["sex"] == "female") | (titanic["survived"]==1)
titanic.loc[target,'age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
seoul_apt["시군구"].isin(
    ["서울특별시 강남구 역삼동","서울특별시 강남구 삼성동"]).sum()
# Out:
# 363
